# %% [markdown]
# <a href="https://colab.research.google.com/github/AisRB/Education/blob/main/course_da_TumGU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 3 Базовые операции с данными на языке Python

# %% [markdown]
# ## 3.1 Визуализация данных

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Education/data/students.csv', sep = ',')

# %%
df
# Out:
#      Age  Growth  Shoe size  Course number  Year of birth  Friend number  \
# 0     20     170         40              2           2002            100
# 1     22     191         43              7           2000            307
# 2     21     172         41              4           2000            186
# 3     19     168         38              2           2003            604
# 4     23     159         36              1           1998            144
# ..   ...     ...        ...            ...            ...            ...
# 181   23     168         39              7           1999            228
# 182   19     169         38              1           2003              0
# 183   18     161         37              2           2003             11
# 184   19     169         41              1           2003             22
# 185   18     164         39              2           2003            500
#
#      Russian rating  Maths rating  Physics rating  Computer science rating  \
# ...

# %%
sns.displot(data=df, x='Growth')

# %%
sns.displot(data=df, x='Growth', kind = 'kde')

# %%
sns.scatterplot(data = df, x = 'Growth', y = 'Weight', hue = 'Sex')

# %%
#визуализиция категориальных признаков: countplot
sns.countplot(x = df['Sex'])

# %%
sns.countplot(data = df, x = 'Sex', hue = 'Animal')

# %%
sns.countplot(data = df, x = 'Animal', hue = 'Sex')

# %%
df_cut = df[['Age', 'Growth', 'Weight', 'Shoe size', 'Sex']]
df_cut.head()
# Out:
#    Age  Growth  Weight  Shoe size      Sex
# 0   20     170    64.0         40  женский
# 1   22     191    73.0         43  мужской
# 2   21     172    60.0         41  мужской
# 3   19     168    59.0         38  женский
# 4   23     159    57.0         36  женский

# %%
sns.pairplot(df_cut)

# %%
sns.pairplot(df_cut, hue = 'Sex')

# %% [markdown]
# ## 3.2 Пропуски в данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
df2 = df.fillna(df.mean())
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %% [markdown]
# ## 3.3 Выбросы и аномалии
# Аномалии в данных и их автоматический поиск

# %% [markdown]
# Средство визуализации - ящик с усами

# %%
sns.boxplot(df.Age)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df.Growth)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(df.Weight)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Первая Процедура поиска выбросов
#
# m - среднее значение признака .mean()
#
# s - отклонение признака .std()
#
# Построить интервал [m-3s, m+3s]. Все объекты, значение признака которых не попадет в этот интервал, нужно объявить выбросами и удалить из таблицы.
#
# Поицем выбросы относительно признака "ВЕС"

# %%
m = df['Weight'].mean()
s = df['Weight'].std()
m - 3 * s, m + 3 * s
# Out:
# (14.52494740231539, 113.53874686520054)

# %%
df = df[(df['Weight'] < m + 3 * s) & (df['Weight'] > m - 3 * s)]
sns.boxplot(df['Weight'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
m = df['Age'].mean()
s = df['Age'].std()
m - 3 * s, m + 3 * s
# Out:
# (13.016722543916735, 27.87216634497215)

# %%
df=df[(df['Age']<m+3*s) & (df['Age']>m-3*s)]
sns.boxplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Вторая процедура поиска выбросов

# %% [markdown]
# a - 25-ая процентиль признака
#
# b - 75-ая процентиль признака
#
# Построим интервал:
#
# [a-1.5(b-a), b+1.5(b-a)]
#
# Значения признака, не попавшего в указаннный интервал объявить выбросам

# %%
df = pd.read_csv('/content/drive/MyDrive/Education/data/students.csv', sep = ',')
#заново загрузим данные, так как мы раньше изменяли таблицу df

# %%
df.describe()
# Out:
#               Age      Growth   Shoe size  Course number  Year of birth  \
# count  186.000000  186.000000  186.000000     186.000000     186.000000
# mean    20.688172  170.661290   39.715054       3.500000    1991.107527
# std      3.468713    9.055881    2.814920       3.147285     132.099550
# min     17.000000  153.000000   34.000000       0.000000     200.000000
# 25%     19.000000  164.000000   38.000000       2.000000    2000.000000
# 50%     20.000000  169.000000   39.000000       3.000000    2001.500000
# 75%     21.000000  178.000000   42.000000       4.000000    2003.000000
# max     55.000000  197.000000   48.000000      37.000000    2004.000000
#
#        Friend number  Russian rating  Maths rating  Physics rating  \
# count     186.000000      186.000000    186.000000      186.000000
# mean      374.032258       81.634409     58.177419       13.182796
# std      2199.541507       14.325019     29.575478       26.414552
# ...

# %%
df.quantile(0.5)
# Out:
# Age                                20.0
# Growth                            169.0
# Shoe size                          39.0
# Course number                       3.0
# Year of birth                    2001.5
# Friend number                     130.0
# Russian rating                     85.0
# Maths rating                       70.0
# Physics rating                      0.0
# Computer science rating             0.0
# Chemistry rating                    0.0
# Literature rating                   0.0
# History rating                      0.0
# Geography rating                    0.0
# Biology rating                      0.0
# Foreign language rating             0.0
# Social science rating               0.0
# Distance to home km                23.5
# Minutes to first class             60.0
# Children number                     1.5
# Removed teeth                       0.0
# Weight                             60.0
# Month of birthday                   6.0
# ...

# %%
df.Age.quantile(0.25), df.Age.quantile(0.75)
# Out:
# (19.0, 21.0)

# %%
a = df.Age.quantile(0.25)
b = df.Age.quantile(0.75)

# %%
a-1.5*(b-a), b+1.5*(b-a)
# Out:
# (16.0, 24.0)

# %%
df=df[(df['Age']<b+1.5*(b-a)) & (df['Age']>a-1.5*(b-a))]
sns.boxplot(df['Age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## 3.4 Класстеризация

# %%
import pandas as pd
import seaborn as sns 
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('/content/drive/MyDrive/Education/data/students.csv', sep = ',')
df_cut = df[['Weight', 'Growth', 'Sex']]

# %%
df_cut.shape
# Out:
# (186, 3)

# %%
df_cut = df_cut.dropna()

# %%
kmeans = KMeans(n_clusters = 2, random_state = 0)
kmeans.fit(df_cut[['Weight', 'Growth']])
df_cut['Label'] = kmeans.labels_

# %%
df_cut.head(20)
# Out:
#     Weight  Growth      Sex  Label
# 0     64.0     170  женский      1
# 1     73.0     191  мужской      0
# 2     60.0     172  мужской      1
# 3     59.0     168  женский      1
# 4     57.0     159  женский      1
# 5     50.0     177  мужской      1
# 6     55.0     180  мужской      1
# 7    120.0     180  мужской      0
# 8     69.0     185  мужской      0
# 9     58.0     168  женский      1
# 10    47.0     158  женский      1
# 11    98.0     183  мужской      0
# 15    48.0     166  женский      1
# 16    64.0     185  мужской      0
# 17    60.0     183  мужской      1
# 18    53.0     167  женский      1
# 19    59.0     164  женский      1
# 20    93.0     186  мужской      0
# 21    55.0     168  женский      1
# 22    56.0     158  женский      1

# %%
sns.scatterplot(data = df_cut, x = 'Weight', y = 'Growth', hue = 'Label')

# %% [markdown]
# # 4  Методы машинного обучения: базовый уровень

# %% [markdown]
# ## 4.1 Задача предсказания и регрессия

# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/drive/MyDrive/Education/data/students.csv', sep = ',')
df_cut = df[['Growth', 'Shoe size']]
df_cut = df_cut.dropna()

# %%
sns.scatterplot(data = df_cut, x = 'Shoe size', y = 'Growth')

# %% [markdown]
# Гипотеза: рост линейно зависит от размера обуви.
#
# Growth = a * ShSize + b
#
# Коэффициенты a,b неизвестны
#
# Модель линейной регрессии умеет находить оптимальные коэффициенты

# %%
linearRegression = LinearRegression()
result = linearRegression.fit(df_cut['Shoe size'].values.reshape(-1, 1), y = df_cut['Growth'].values)

# %%
result.coef_, result.intercept_
# Out:
# (array([2.77717058]), 60.36581125736733)

# %%
df_cut['Predicted_growth'] = result.predict(df_cut['Shoe size'].values.reshape(-1, 1))

# %%
df_cut[['Growth', 'Predicted_growth']].head()
# Out:
#    Growth  Predicted_growth
# 0     170        171.452635
# 1     191        179.784146
# 2     172        174.229805
# 3     168        165.898293
# 4     159        160.343952

# %%
from numpy.core.fromnumeric import mean
from sklearn.metrics import mean_absolute_error
mean_absolute_error(df_cut['Growth'], df_cut['Predicted_growth'])
# Out:
# 3.450698681998386

# %%
df_cut=df[['MIddle and index finger','Middle and ring finger','Middle and little finger']]

# %%
results = linearRegression.fit(df_cut[['Middle and ring finger','Middle and little finger']].values.reshape(-1, 2), y=df_cut['MIddle and index finger'].values)
results.coef_ , results.intercept_
# Out:
# (array([0.10731496, 0.04389948]), 7.436145518798954)

# %% [markdown]
# MIddle and index finger = 0.107 * Middle and ring finger + 0.04 * Middle and little finger + 7.44

# %%
df_cut['Predicted']=results.predict(df_cut[['Middle and ring finger','Middle and little finger']].values.reshape(-1, 2))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
mean_absolute_error(df_cut['Predicted'], df_cut['MIddle and index finger'])
# Out:
# 3.094567105647603

# %% [markdown]
# ### Проверка точности модели на новой выборке

# %% [markdown]
# До этого момента мы тренировали модель и проверяли ее качество (mean_absolute_error) на одних и тех же данных.
#
# Вообще говоря, это читерство, так как модель была построена **с участием данных**, на которых она потом проверяется.
#
# Поэтому в анализе данных поступают так:
#
# У вас есть **две** таблицы: **тренировочная и тестовая выборка.**
#
# Модель строится по **тренировочной** выборке. Качество ее проверяется по **тестовой** выборке.
#
# Сейчас мы это реализуем. Загружаем второую таблицу со студентами, которая не использовалась ранее:

# %%
df_test=pd.read_csv('/content/drive/MyDrive/Education/data/students_test.csv', delimiter=',')
df_test_cut=df_test[['MIddle and index finger','Middle and ring finger','Middle and little finger']]

# %% [markdown]
# Внимание: через функцию predict прогоняем объекты тестовой выборки

# %%
df_test_cut['Predicted']=results.predict(df_test_cut[['Middle and ring finger','Middle and little finger']].values.reshape(-1, 2))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_test_cut.head()
# Out:
#    MIddle and index finger  Middle and ring finger  Middle and little finger  \
# 0                      3.0                       5                        12
# 1                      9.0                      12                        50
# 2                      7.0                      14                        40
# 3                      5.0                       7                        10
# 4                     10.0                      10                        35
#
#    Predicted
# 0   8.499514
# 1  10.918899
# 2  10.694534
# 3   8.626345
# 4  10.045777

# %%
mean_absolute_error(df_test_cut['Predicted'], df_test_cut['MIddle and index finger'])
# Out:
# 4.680118432328658

# %% [markdown]
# ## 4.2 Алгоритмы классификации

# %% [markdown]
# ### Задача классификации. Метод k ближайших соседей (kNN)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
# подключение библиотеки с методом Ближайшего соседа

# %%
df=pd.read_csv('/content/drive/MyDrive/Education/data/students.csv', delimiter=',')
df_cut=df[['Growth','Weight','Sex']]
df_cut=df_cut.dropna()

# %%
sns.scatterplot(data=df_cut, x='Weight', y='Growth', hue='Sex')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_cut[['Weight', 'Growth']].values.reshape(-1, 2))
arr=scaler.transform(df_cut[['Weight', 'Growth']].values.reshape(-1, 2))

# %% [markdown]
# Гипотеза: мужчины и женщины образуют два облака. Причем для многих точек выполнено условие: если соседние точки мужчины (женщины), то и данная точка - мужчина (женщина)

# %%
model = KNeighborsClassifier(n_neighbors=3)
model.fit(arr, y=df_cut['Sex'].values)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Загружаем тестовую выбоку

# %%
df_test=pd.read_csv('/content/drive/MyDrive/Education/data/students_test.csv', delimiter=',')
df_test_cut=df_test[['Growth','Weight','Sex']]
df_test_cut=df_test_cut.dropna()

# %%
arr_test=scaler.transform(df_test_cut[['Weight', 'Growth']].values.reshape(-1, 2))

# %% [markdown]
# Внимание: через функцию predict прогоняем объекты тестовой выборки

# %%
df_test_cut['Predicted']=model.predict(arr_test)

# %% [markdown]
# Метрики качества задачи классификации

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
print(accuracy_score(df_test_cut['Predicted'], df_test_cut['Sex']))
# это процент правильно классифицированных объектов
# Out:
# 0.8701298701298701

# %%
print(precision_score(df_test_cut['Predicted'], df_test_cut['Sex'],average=None, zero_division=1))
print(recall_score(df_test_cut['Predicted'], df_test_cut['Sex'],average=None, zero_division=1))
# Out:
# [0.85106383 0.9       ]
# [0.93023256 0.79411765]

# %%
pd.crosstab(df_test_cut['Predicted'],df_test_cut['Sex'])
# Out:
# Sex        женский  мужской
# Predicted
# женский         40        3
# мужской          7       27

# %%
df_test_cut['Code']='0'
df_test_cut.loc[(df_test_cut['Sex']=='мужской') & (df_test_cut['Predicted']=='женский'),'Code']='1'
df_test_cut.loc[(df_test_cut['Sex']=='женский') & (df_test_cut['Predicted']=='мужской'),'Code']='2'

# %%
sns.scatterplot(data=df_test_cut, x='Weight', y='Growth', hue='Code')

# %% [markdown]
# ### Задача классификации. Линейный классификатор

# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import SGDClassifier

# %%
df=pd.read_csv('/content/drive/MyDrive/Education/data/students.csv', delimiter=',')
df_cut=df[['Growth','Weight','Sex']]
df_cut=df_cut.dropna()

# %%
sns.scatterplot(data=df_cut, x='Weight', y='Growth', hue='Sex')

# %% [markdown]
# Гипотеза: мужчины и женщины образуют два облака. Эти облака можно попытаться разделить прямой линией.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df_cut[['Weight', 'Growth']].values.reshape(-1, 2))
arr=scaler.transform(df_cut[['Weight', 'Growth']].values.reshape(-1, 2))

# %%
model=SGDClassifier()
model.fit(arr, y=df_cut['Sex'].values)
# Out:
# SGDClassifier()

# %% [markdown]
# Загружаем тестовую выбоку

# %%
df_test=pd.read_csv('/content/drive/MyDrive/Education/data/students_test.csv', delimiter=',')
df_test_cut=df_test[['Growth','Weight','Sex']]
df_test_cut=df_test_cut.dropna()

# %%
arr_test=scaler.transform(df_test_cut[['Weight', 'Growth']].values.reshape(-1, 2))

# %% [markdown]
# Внимание: через функцию predict прогоняем объекты тестовой выборки

# %%
df_test_cut['Predicted']=model.predict(arr_test)

# %%
df_test_cut.head()
# Out:
#    Growth  Weight      Sex Predicted
# 0   180.0    78.0  мужской   мужской
# 1   167.0    50.0  женский   женский
# 2   178.0    70.0  женский   мужской
# 3   156.0    47.0  женский   женский
# 4   186.0    94.0  мужской   мужской

# %% [markdown]
# Метрики качества задачи классификации

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

# %%
print(accuracy_score(df_test_cut['Predicted'], df_test_cut['Sex']))
# это процент правильно классифицированных объектов
# Out:
# 0.8831168831168831

# %%
print(precision_score(df_test_cut['Predicted'], df_test_cut['Sex'],average=None, zero_division=1))
print(recall_score(df_test_cut['Predicted'], df_test_cut['Sex'],average=None, zero_division=1))
# Out:
# [0.89361702 0.86666667]
# [0.91304348 0.83870968]

# %%
pd.crosstab(df_test_cut['Predicted'],df_test_cut['Sex'])
# Out:
# Sex        женский  мужской
# Predicted
# женский         42        4
# мужской          5       26

# %%
df_test_cut['Code']='0'
df_test_cut.loc[(df_test_cut['Sex']=='мужской') & (df_test_cut['Predicted']=='женский'),'Code']='1'
df_test_cut.loc[(df_test_cut['Sex']=='женский') & (df_test_cut['Predicted']=='мужской'),'Code']='2'

# %%
sns.scatterplot(data=df_test_cut, x='Weight', y='Growth', hue='Code')

# %% [markdown]
# # 5  Методы машинного обучения: продвинутый уровень

# %% [markdown]
# ## 5.1 Решающие деревья

# %% [markdown]
# ### Задача классификации. Дерево решений.

# %%
 import pandas as pd
 import seaborn as sns
 from sklearn import tree

# %%
df = pd.read_csv('/content/drive/MyDrive/Education/data/students.csv', sep = ',')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 48 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age                          186 non-null    int64
#  1   Growth                       186 non-null    int64
#  2   Shoe size                    186 non-null    int64
#  3   Course number                186 non-null    int64
#  4   Year of birth                186 non-null    int64
#  5   Friend number                186 non-null    int64
#  6   Russian rating               186 non-null    int64
#  7   Maths rating                 186 non-null    int64
#  8   Physics rating               186 non-null    int64
#  9   Computer science rating      186 non-null    int64
#  10  Chemistry rating             186 non-null    int64
#  11  Literature rating            186 non-null    int64
#  12  History rating               186 non-null    int64
# ...

# %%
df_cut = df[['Growth', 'Weight', 'Sex', 'Hair length', 'Children number']]
df_cut = df_cut.dropna()

# %%
sns.pairplot(df_cut, hue = 'Sex')

# %% [markdown]
# Гипотеза: угадать пол человека можно за небольшое количество вопросов. И модель эти вопросы найдет автоматически.

# %%
model = tree.DecisionTreeClassifier(max_depth=3) # max_depth - это глубина дерева
model.fit(df_cut[['Growth', 'Weight', 'Hair length', 'Children number']].values.reshape(-1, 4), y = df_cut['Sex'].values)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
import graphviz 
dot_data = tree.export_graphviz(model, out_file=None, 
                      feature_names=['Growth', 'Weight', 'Hair length', 'Children number'],  
                      class_names=['f', 'm'],  
                     filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# Загружаем тестовую выбоку

# %%
df_test=pd.read_csv('/content/drive/MyDrive/Education/data/students_test.csv', delimiter=',')
df_test_cut=df_test[['Growth','Weight','Sex','Hair length','Children number']]
df_test_cut=df_test_cut.dropna()

# %% [markdown]
# Внимание: через функцию predict прогоняем объекты тестовой выборки

# %%
df_test_cut['Predicted']=model.predict(df_test_cut[['Growth','Weight','Hair length','Children number']].values.reshape(-1,4))

# %% [markdown]
# Метрики качества задачи классификации

# %%
pd.crosstab(df_test_cut['Predicted'],df_test_cut['Sex'])
# Out:
# Sex        женский  мужской
# Predicted
# женский         41        1
# мужской          1       25

# %%
df_test_cut['Code']='0'
df_test_cut.loc[(df_test_cut['Sex']=='мужской') & (df_test_cut['Predicted']=='женский'),'Code']='1'
df_test_cut.loc[(df_test_cut['Sex']=='женский') & (df_test_cut['Predicted']=='мужской'),'Code']='2'

# %%
sns.scatterplot(data=df_test_cut, x='Weight', y='Growth', hue='Code')

# %% [markdown]
# Так считаются метрики качества в задаче классификации
#
# Есть два показателя: precision и recall. Их можно подсчитать для каждого класса.
#
# **recall(для женщин)=доля правильно предсказанных женщин среди среди всех женщин**
#
# В нашем примере: recall(для женщин)=40/(40+2)=0.9523809523809523
#
# **recall(для мужчин)=доля правильно предсказанных мужчин среди среди всех мужчин**
#
# В нашем примере: recall(для мужчин)=25/(25+1)=0.9615384615384616
#
# **precision(для женщин)=доля истинных женщин среди людей, отнесенных ИИ к женщинам**
#
# В нашем примере: precision(для женщин)=40/(40+1)=0.975609756097561
#
# **precision(для мужчин)=доля истинных мужчин среди людей, отнесенных ИИ к мужчинам**
#
# В нашем примере: precision(для мужчин)=25/(25+2)=0.9259259259259259

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(df_test_cut['Sex'], df_test_cut['Predicted'])
# Out:
# (array([0.97619048, 0.96153846]),
#  array([0.97619048, 0.96153846]),
#  array([0.97619048, 0.96153846]),
#  array([42, 26]))

# %% [markdown]
# ### Задача регрессии. Дерево решений

# %%
import pandas as pd
import seaborn as sns
from sklearn import tree

# %%
df = pd.read_csv('/content/drive/MyDrive/Education/data/students.csv', sep = ',')

# %%
df_cut = df[['Growth', 'Weight', 'Hair length', 'Shoe size']]
df_cut = df_cut.dropna()

# %%
sns.pairplot(df_cut)

# %% [markdown]
# Гипотеза: угадать рост человека можно за небольшое количество вопросов. И модель эти вопросы найдет автоматически.

# %%
model=tree.DecisionTreeRegressor(max_depth=2)
model.fit(df_cut[['Weight','Hair length','Shoe size']].values.reshape(-1,3), y=df_cut['Growth'].values)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
import graphviz 
dot_data = tree.export_graphviz(model, out_file=None, 
                      feature_names=['Weight','Hair length','Shoe size'],  
                      class_names='Growths',  
                     filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# Загружаем тестовую выбоку

# %%
df_test=pd.read_csv('/content/drive/MyDrive/Education/data/students_test.csv', delimiter=',')
df_test_cut=df_test[['Growth','Weight','Hair length','Shoe size']]
df_test_cut=df_test_cut.dropna()

# %% [markdown]
# Внимание: через функцию predict прогоняем объекты **тестовой** выборки

# %%
df_test_cut['Predicted']=model.predict(df_test_cut[['Weight','Hair length','Shoe size']].values.reshape(-1,3))

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(df_test_cut['Growth'], df_test_cut['Predicted'])
# Out:
# 4.351558902090816

# %% [markdown]
# ## 5.2 Бустинг и ансамбли алгоритмов

# %% [markdown]
# ### Задача классификации. Random forest

# %%
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv('/content/drive/MyDrive/Education/data/students.csv', delimiter=',')

# %%
df_cut=df[['Growth','Weight','Sex','Hair length','Children number']]
df_cut=df_cut.dropna()

# %%
sns.pairplot(df_cut, hue='Sex')

# %% [markdown]
# Гипотеза: угадать пол человека можно за небольшое количество вопросов. И модель эти вопросы найдет автоматически.

# %%
model = RandomForestClassifier(max_depth=2, random_state=0)
model.fit(df_cut[['Growth','Weight','Hair length','Children number']].values.reshape(-1,4), y=df_cut['Sex'].values)
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %% [markdown]
# Загружаем тестовую выбоку

# %%
df_test=pd.read_csv('/content/drive/MyDrive/Education/data/students_test.csv', delimiter=',')
df_test_cut=df_test[['Growth','Weight','Sex','Hair length','Children number']]
df_test_cut=df_test_cut.dropna()

# %% [markdown]
# Внимание: через функцию predict прогоняем объекты **тестовой** выборки

# %%
df_test_cut['Predicted']=model.predict(df_test_cut[['Growth','Weight','Hair length','Children number']].values.reshape(-1,4))

# %% [markdown]
# Метрики качества задачи классификации

# %%
pd.crosstab(df_test_cut['Predicted'],df_test_cut['Sex'])
# Out:
# Sex        женский  мужской
# Predicted
# женский         42        1
# мужской          0       25

# %%
df_test_cut['Code']='0'
df_test_cut.loc[(df_test_cut['Sex']=='мужской') & (df_test_cut['Predicted']=='женский'),'Code']='1'
df_test_cut.loc[(df_test_cut['Sex']=='женский') & (df_test_cut['Predicted']=='мужской'),'Code']='2'

# %%
sns.scatterplot(data = df_test_cut, x = 'Weight', y = 'Growth', hue = 'Code')

# %%
# Кто же он, человек сломавший Random Forest?
df_test_cut[df_test_cut['Code']=='1']
# Out:
#     Growth  Weight      Sex  Hair length  Children number Predicted Code
# 78   175.0    50.0  мужской         40.0              2.0   женский    1
